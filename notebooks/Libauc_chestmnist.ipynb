# %% [markdown]
# LibAUC Experiments

# %%
from libauc.models import resnet18
from libauc.losses import AUCMLoss

from tqdm import tqdm
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as torch_data
import torchvision.transforms as transforms

import medmnist
from medmnist import INFO, Evaluator


from libauc.losses import AUCMLoss, CrossEntropyLoss
from libauc.optimizers import PESG, Adam
from libauc.models import densenet121 as DenseNet121
from libauc.datasets import CheXpert

import torch 
from PIL import Image
import numpy as np
import torchvision.transforms as transforms
from torch.utils.data import Dataset
from sklearn.metrics import roc_auc_score

import warnings
warnings.filterwarnings("ignore")

# %%
data_flag = 'breastmnist'
# data_flag = 'chestmnist'
download = True

NUM_EPOCHS = 3
BATCH_SIZE = 128
lr = 0.001

info = INFO[data_flag]
task = info['task']
n_channels = info['n_channels']
n_classes = len(info['label'])

DataClass = getattr(medmnist, info['python_class'])

# %%
task
# Out:
# 'binary-class'

# %%
data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.ToPILImage(),
            transforms.Grayscale(3),
            transforms.ToTensor(),
            transforms.Normalize(0.5, 0.5),
        ])

# load the data
train_dataset = DataClass(split='train', transform=data_transform, download=download)
val_dataset = DataClass(split='val', transform=data_transform, download=download)
test_dataset = DataClass(split='test', transform=data_transform, download=download)

pil_dataset = DataClass(split='train', download=download)

# encapsulate data into dataloader form
train_loader = torch_data.DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = torch_data.DataLoader(dataset=val_dataset, batch_size=2*BATCH_SIZE, shuffle=False)
test_loader = torch_data.DataLoader(dataset=test_dataset, batch_size=2*BATCH_SIZE, shuffle=False)
# Out:
# Using downloaded and verified file: C:\Users\Hari\.medmnist\breastmnist.npz
# Using downloaded and verified file: C:\Users\Hari\.medmnist\breastmnist.npz
# Using downloaded and verified file: C:\Users\Hari\.medmnist\breastmnist.npz
# Using downloaded and verified file: C:\Users\Hari\.medmnist\breastmnist.npz

# %%
lr = 0.01 # using smaller learning rate is better
epoch_decay = 2e-5
weight_decay = 1e-7
margin = 1.0

model = resnet18(num_classes=2)
model = model.cuda()
# criterion = nn.CrossEntropyLoss()  
# optimizer = optim.Adam(model.parameters(), lr=lr)
criterion = AUCMLoss()
optimizer = PESG(model, 
                 loss_fn=criterion, 
                 lr=lr, 
                 margin=margin, 
                 epoch_decay=epoch_decay, 
                 weight_decay=weight_decay)
CE_loss = nn.CrossEntropyLoss()
# training
best_val_auc = 0 
for epoch in range(1001):
    train_losses = []
    for idx, data in enumerate(train_loader):
      print("Iteration started")
      train_data, train_labels = data
      train_data, train_labels  = train_data.cuda(), train_labels.cuda()
      y_pred = model(train_data)
      y_pred = torch.sigmoid(y_pred)
      loss = criterion(y_pred, train_labels.type(torch.LongTensor).cuda())
      train_losses.append(loss.item()/len(data))
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      break

    print("Epoch : {:03d}  Train Loss : {:.5f} ".format(epoch, np.mean(train_losses)), end='')
    model.eval()
    with torch.no_grad():    
        test_pred = []
        test_true = [] 
        test_losses = []
        test_CE_losses = []
        for jdx, data in enumerate(val_loader):
            test_data, test_labels = data
            test_data = test_data.cuda()
            y_pred = model(test_data)
            test_pred.append(y_pred.cpu().detach().numpy())
            test_true.append(test_labels.numpy())
            test_losses.append(criterion(y_pred, test_labels.squeeze().type(torch.LongTensor).cuda()).item() / len(data))
            # test_CE_losses.append(CE_loss(y_pred, test_labels.squeeze().float().cuda()).cpu())

        test_true = np.concatenate(test_true)
        test_pred = np.concatenate(test_pred)

        # val_auc_mean = 0
        # for i in range(14):
        val_auc =  roc_auc_score(test_true, test_pred[:,1]) 
        # val_auc_mean/=14
        print("Val Loss : {:.5f}   ".format(np.mean(test_losses)), end = '')
        model.train()

        if best_val_auc < val_auc:
            best_val_auc = val_auc
            torch.save(model.state_dict(), 'pretrained_model.pth')

        print ('BatchID= {}   Val_AUC={:.4f}   Best_Val_AUC={:.4f}'.format(
            idx, val_auc, best_val_auc ))
          
    print("Epoch : {}".format(epoch))
# Out:
# Iteration started
# Epoch : 000  Train Loss : 0.07435 Val Loss : 0.00391   BatchID= 0   Val_AUC=0.5589   Best_Val_AUC=0.5589
# Epoch : 0
# Iteration started
# Epoch : 001  Train Loss : 0.07070 Val Loss : 0.00783   BatchID= 0   Val_AUC=0.6349   Best_Val_AUC=0.6349
# Epoch : 1
# Iteration started
# Epoch : 002  Train Loss : 0.06626 Val Loss : 0.01184   BatchID= 0   Val_AUC=0.5196   Best_Val_AUC=0.6349
# Epoch : 2
# Iteration started
# Epoch : 003  Train Loss : 0.06046 Val Loss : 0.01608   BatchID= 0   Val_AUC=0.4912   Best_Val_AUC=0.6349
# Epoch : 3
# Iteration started
# Epoch : 004  Train Loss : 0.05055 Val Loss : 0.02063   BatchID= 0   Val_AUC=0.4929   Best_Val_AUC=0.6349
# Epoch : 4
# Iteration started
# Epoch : 005  Train Loss : 0.04325 Val Loss : 0.02556   BatchID= 0   Val_AUC=0.4887   Best_Val_AUC=0.6349
# Epoch : 5
# Iteration started
# Epoch : 006  Train Loss : 0.05455 Val Loss : 0.03132   BatchID= 0   Val_AUC=0.4904   Best_Val_AUC=0.6349
# Epoch : 6
# Iteration started
# Epoch : 007  Train Loss : 0.03965 Val Loss : 0.03688   BatchID= 0   Val_AUC=0.5221   Best_Val_AUC=0.6349
# Epoch : 7
# Iteration started
# Epoch : 008  Train Loss : 0.04553 Val Loss : 0.04322   BatchID= 0   Val_AUC=0.5530   Best_Val_AUC=0.6349
# Epoch : 8
# Iteration started
# Epoch : 009  Train Loss : 0.04656 Val Loss : 0.05003   BatchID= 0   Val_AUC=0.5622   Best_Val_AUC=0.6349
# Epoch : 9
# Iteration started
# Epoch : 010  Train Loss : 0.04843 Val Loss : 0.05787   BatchID= 0   Val_AUC=0.5581   Best_Val_AUC=0.6349
# Epoch : 10
# Iteration started
# Epoch : 011  Train Loss : 0.04504 Val Loss : 0.06672   BatchID= 0   Val_AUC=0.5547   Best_Val_AUC=0.6349
# Epoch : 11
# Iteration started
# Epoch : 012  Train Loss : 0.05161 Val Loss : 0.07717   BatchID= 0   Val_AUC=0.5856   Best_Val_AUC=0.6349
# Epoch : 12
# Iteration started
# Epoch : 013  Train Loss : 0.04727 Val Loss : 0.08783   BatchID= 0   Val_AUC=0.5739   Best_Val_AUC=0.6349
# Epoch : 13
# Iteration started
# Epoch : 014  Train Loss : 0.04732 Val Loss : 0.09976   BatchID= 0   Val_AUC=0.5505   Best_Val_AUC=0.6349
# Epoch : 14
# Iteration started
# Epoch : 015  Train Loss : 0.05403 Val Loss : 0.11288   BatchID= 0   Val_AUC=0.5338   Best_Val_AUC=0.6349
# Epoch : 15
# Iteration started
# Epoch : 016  Train Loss : 0.04358 Val Loss : 0.12720   BatchID= 0   Val_AUC=0.5088   Best_Val_AUC=0.6349
# Epoch : 16
# Iteration started
# Epoch : 017  Train Loss : 0.04854 Val Loss : 0.14326   BatchID= 0   Val_AUC=0.4779   Best_Val_AUC=0.6349
# Epoch : 17
# Iteration started
# Epoch : 018  Train Loss : 0.05157 Val Loss : 0.15801   BatchID= 0   Val_AUC=0.4561   Best_Val_AUC=0.6349
# Epoch : 18
# Iteration started
# Epoch : 019  Train Loss : 0.04777 Val Loss : 0.17715   BatchID= 0   Val_AUC=0.4486   Best_Val_AUC=0.6349
# Epoch : 19
# Iteration started
# Epoch : 020  Train Loss : 0.04423 Val Loss : 0.19502   BatchID= 0   Val_AUC=0.4536   Best_Val_AUC=0.6349
# Epoch : 20
# Iteration started
# Epoch : 021  Train Loss : 0.05748 Val Loss : 0.21871   BatchID= 0   Val_AUC=0.4536   Best_Val_AUC=0.6349
# Epoch : 21
# Iteration started
# Epoch : 022  Train Loss : 0.05447 Val Loss : 0.23350   BatchID= 0   Val_AUC=0.4586   Best_Val_AUC=0.6349
# Epoch : 22
# Iteration started
# Epoch : 023  Train Loss : 0.05004 Val Loss : 0.25098   BatchID= 0   Val_AUC=0.4837   Best_Val_AUC=0.6349
# Epoch : 23
# Iteration started
# Epoch : 024  Train Loss : 0.06479 Val Loss : 0.27274   BatchID= 0   Val_AUC=0.5104   Best_Val_AUC=0.6349
# Epoch : 24
# Iteration started
# Epoch : 025  Train Loss : 0.05677 Val Loss : 0.28350   BatchID= 0   Val_AUC=0.5272   Best_Val_AUC=0.6349
# Epoch : 25
# Iteration started
# Epoch : 026  Train Loss : 0.06187 Val Loss : 0.30040   BatchID= 0   Val_AUC=0.5464   Best_Val_AUC=0.6349
# Epoch : 26
# Iteration started
# Epoch : 027  Train Loss : 0.06334 Val Loss : 0.30886   BatchID= 0   Val_AUC=0.5380   Best_Val_AUC=0.6349
# Epoch : 27
# Iteration started
# Epoch : 028  Train Loss : 0.06623 Val Loss : 0.32435   BatchID= 0   Val_AUC=0.5530   Best_Val_AUC=0.6349
# Epoch : 28
# Iteration started
# Epoch : 029  Train Loss : 0.05355 Val Loss : 0.32899   BatchID= 0   Val_AUC=0.5313   Best_Val_AUC=0.6349
# Epoch : 29
# Iteration started
# Epoch : 030  Train Loss : 0.05864 Val Loss : 0.34384   BatchID= 0   Val_AUC=0.5313   Best_Val_AUC=0.6349
# Epoch : 30
# Iteration started
# Epoch : 031  Train Loss : 0.06773 Val Loss : 0.34401   BatchID= 0   Val_AUC=0.5138   Best_Val_AUC=0.6349
# Epoch : 31
# Iteration started
# Epoch : 032  Train Loss : 0.05907 Val Loss : 0.35121   BatchID= 0   Val_AUC=0.5054   Best_Val_AUC=0.6349
# Epoch : 32
# Iteration started
# Epoch : 033  Train Loss : 0.06068 Val Loss : 0.35872   BatchID= 0   Val_AUC=0.5155   Best_Val_AUC=0.6349
# Epoch : 33
# Iteration started
# Epoch : 034  Train Loss : 0.06712 Val Loss : 0.36225   BatchID= 0   Val_AUC=0.4971   Best_Val_AUC=0.6349
# Epoch : 34
# Iteration started
# Epoch : 035  Train Loss : 0.06240 Val Loss : 0.36865   BatchID= 0   Val_AUC=0.5063   Best_Val_AUC=0.6349
# Epoch : 35
# Iteration started
# Epoch : 036  Train Loss : 0.06114 Val Loss : 0.37443   BatchID= 0   Val_AUC=0.5029   Best_Val_AUC=0.6349
# Epoch : 36
# Iteration started
# Epoch : 037  Train Loss : 0.06069 Val Loss : 0.37272   BatchID= 0   Val_AUC=0.4996   Best_Val_AUC=0.6349
# Epoch : 37
# Iteration started
# Epoch : 038  Train Loss : 0.05841 Val Loss : 0.37130   BatchID= 0   Val_AUC=0.5113   Best_Val_AUC=0.6349
# Epoch : 38
# Iteration started
# Epoch : 039  Train Loss : 0.05915 Val Loss : 0.37349   BatchID= 0   Val_AUC=0.5280   Best_Val_AUC=0.6349
# Epoch : 39
# Iteration started
# Epoch : 040  Train Loss : 0.06422 Val Loss : 0.37532   BatchID= 0   Val_AUC=0.5221   Best_Val_AUC=0.6349
# Epoch : 40
# Iteration started
# Epoch : 041  Train Loss : 0.06580 Val Loss : 0.36268   BatchID= 0   Val_AUC=0.5447   Best_Val_AUC=0.6349
# Epoch : 41
# Iteration started
# Epoch : 042  Train Loss : 0.06170 Val Loss : 0.38121   BatchID= 0   Val_AUC=0.5422   Best_Val_AUC=0.6349
# Epoch : 42
# Iteration started
# Epoch : 043  Train Loss : 0.06841 Val Loss : 0.38115   BatchID= 0   Val_AUC=0.5789   Best_Val_AUC=0.6349
# Epoch : 43
# Iteration started
# Epoch : 044  Train Loss : 0.06235 Val Loss : 0.38779   BatchID= 0   Val_AUC=0.5990   Best_Val_AUC=0.6349
# Epoch : 44
# Iteration started
# Epoch : 045  Train Loss : 0.07493 Val Loss : 0.38744   BatchID= 0   Val_AUC=0.5297   Best_Val_AUC=0.6349
# Epoch : 45
# Iteration started
# Epoch : 046  Train Loss : 0.06893 Val Loss : 0.37956   BatchID= 0   Val_AUC=0.6157   Best_Val_AUC=0.6349
# Epoch : 46
# Iteration started
# Epoch : 047  Train Loss : 0.06414 Val Loss : 0.42881   BatchID= 0   Val_AUC=0.5865   Best_Val_AUC=0.6349
# Epoch : 47
# Iteration started
# Epoch : 048  Train Loss : 0.08068 Val Loss : 0.39645   BatchID= 0   Val_AUC=0.5982   Best_Val_AUC=0.6349
# Epoch : 48
# Iteration started
# Epoch : 049  Train Loss : 0.06813 Val Loss : 0.39904   BatchID= 0   Val_AUC=0.5347   Best_Val_AUC=0.6349
# Epoch : 49
# Iteration started
# Epoch : 050  Train Loss : 0.06832 Val Loss : 0.42845   BatchID= 0   Val_AUC=0.6157   Best_Val_AUC=0.6349
# Epoch : 50
# Iteration started
# Epoch : 051  Train Loss : 0.06943 Val Loss : 0.41575   BatchID= 0   Val_AUC=0.5255   Best_Val_AUC=0.6349
# Epoch : 51
# Iteration started
# Epoch : 052  Train Loss : 0.06132 Val Loss : 0.41677   BatchID= 0   Val_AUC=0.5965   Best_Val_AUC=0.6349
# Epoch : 52
# Iteration started
# Epoch : 053  Train Loss : 0.05998 Val Loss : 0.41892   BatchID= 0   Val_AUC=0.5706   Best_Val_AUC=0.6349
# Epoch : 53
# Iteration started
# Epoch : 054  Train Loss : 0.07761 Val Loss : 0.44926   BatchID= 0   Val_AUC=0.6775   Best_Val_AUC=0.6775
# Epoch : 54
# Iteration started
# Epoch : 055  Train Loss : 0.06459 Val Loss : 0.43738   BatchID= 0   Val_AUC=0.6792   Best_Val_AUC=0.6792
# Epoch : 55
# Iteration started
# Epoch : 056  Train Loss : 0.05835 Val Loss : 0.46522   BatchID= 0   Val_AUC=0.6508   Best_Val_AUC=0.6792
# Epoch : 56
# Iteration started
# Epoch : 057  Train Loss : 0.06878 Val Loss : 0.42708   BatchID= 0   Val_AUC=0.6550   Best_Val_AUC=0.6792
# Epoch : 57
# Iteration started
# Epoch : 058  Train Loss : 0.06097 Val Loss : 0.46669   BatchID= 0   Val_AUC=0.6876   Best_Val_AUC=0.6876
# Epoch : 58
# Iteration started
# Epoch : 059  Train Loss : 0.05781 Val Loss : 0.43524   BatchID= 0   Val_AUC=0.6475   Best_Val_AUC=0.6876
# Epoch : 59
# Iteration started
# Epoch : 060  Train Loss : 0.05913 Val Loss : 0.45866   BatchID= 0   Val_AUC=0.7469   Best_Val_AUC=0.7469
# Epoch : 60
# Iteration started
# Epoch : 061  Train Loss : 0.05161 Val Loss : 0.45318   BatchID= 0   Val_AUC=0.6859   Best_Val_AUC=0.7469
# Epoch : 61
# Iteration started
# Epoch : 062  Train Loss : 0.05716 Val Loss : 0.51946   BatchID= 0   Val_AUC=0.7970   Best_Val_AUC=0.7970
# Epoch : 62
# Iteration started
# Epoch : 063  Train Loss : 0.05585 Val Loss : 0.44736   BatchID= 0   Val_AUC=0.6700   Best_Val_AUC=0.7970
# Epoch : 63
# Iteration started
# Epoch : 064  Train Loss : 0.06257 Val Loss : 0.48263   BatchID= 0   Val_AUC=0.7978   Best_Val_AUC=0.7978
# Epoch : 64
# Iteration started
# Epoch : 065  Train Loss : 0.06672 Val Loss : 0.44729   BatchID= 0   Val_AUC=0.7753   Best_Val_AUC=0.7978
# Epoch : 65
# Iteration started
# Epoch : 066  Train Loss : 0.06245 Val Loss : 0.51722   BatchID= 0   Val_AUC=0.7945   Best_Val_AUC=0.7978
# Epoch : 66
# Iteration started
# Epoch : 067  Train Loss : 0.05659 Val Loss : 0.47060   BatchID= 0   Val_AUC=0.7711   Best_Val_AUC=0.7978
# Epoch : 67
# Iteration started
# Epoch : 068  Train Loss : 0.05208 Val Loss : 0.45302   BatchID= 0   Val_AUC=0.7778   Best_Val_AUC=0.7978
# Epoch : 68
# Iteration started
# Epoch : 069  Train Loss : 0.05813 Val Loss : 0.48612   BatchID= 0   Val_AUC=0.7820   Best_Val_AUC=0.7978
# Epoch : 69
# Iteration started
# Epoch : 070  Train Loss : 0.05821 Val Loss : 0.45405   BatchID= 0   Val_AUC=0.8129   Best_Val_AUC=0.8129
# Epoch : 70
# Iteration started
# Epoch : 071  Train Loss : 0.05702 Val Loss : 0.49448   BatchID= 0   Val_AUC=0.8028   Best_Val_AUC=0.8129
# Epoch : 71
# Iteration started
# Epoch : 072  Train Loss : 0.05636 Val Loss : 0.47612   BatchID= 0   Val_AUC=0.7678   Best_Val_AUC=0.8129
# Epoch : 72
# Iteration started
# Epoch : 073  Train Loss : 0.05614 Val Loss : 0.54829   BatchID= 0   Val_AUC=0.7928   Best_Val_AUC=0.8129
# Epoch : 73
# Iteration started
# Epoch : 074  Train Loss : 0.05384 Val Loss : 0.48592   BatchID= 0   Val_AUC=0.7644   Best_Val_AUC=0.8129
# Epoch : 74
# Iteration started
# Epoch : 075  Train Loss : 0.05022 Val Loss : 0.54651   BatchID= 0   Val_AUC=0.8112   Best_Val_AUC=0.8129
# Epoch : 75
# Iteration started
# Epoch : 076  Train Loss : 0.04910 Val Loss : 0.40844   BatchID= 0   Val_AUC=0.7678   Best_Val_AUC=0.8129
# Epoch : 76
# Iteration started
# Epoch : 077  Train Loss : 0.05071 Val Loss : 0.60134   BatchID= 0   Val_AUC=0.7820   Best_Val_AUC=0.8129
# Epoch : 77
# Iteration started
# Epoch : 078  Train Loss : 0.04392 Val Loss : 0.41995   BatchID= 0   Val_AUC=0.8053   Best_Val_AUC=0.8129
# Epoch : 78
# Iteration started
# Epoch : 079  Train Loss : 0.04941 Val Loss : 0.47801   BatchID= 0   Val_AUC=0.8312   Best_Val_AUC=0.8312
# Epoch : 79
# Iteration started
# Epoch : 080  Train Loss : 0.04715 Val Loss : 0.40822   BatchID= 0   Val_AUC=0.7794   Best_Val_AUC=0.8312
# Epoch : 80
# Iteration started
# Epoch : 081  Train Loss : 0.05009 Val Loss : 0.40605   BatchID= 0   Val_AUC=0.7661   Best_Val_AUC=0.8312
# Epoch : 81
# Iteration started
# Epoch : 082  Train Loss : 0.04490 Val Loss : 0.51805   BatchID= 0   Val_AUC=0.8145   Best_Val_AUC=0.8312
# Epoch : 82
# Iteration started
# Epoch : 083  Train Loss : 0.04291 Val Loss : 0.46210   BatchID= 0   Val_AUC=0.8279   Best_Val_AUC=0.8312
# Epoch : 83
# Iteration started
# Epoch : 084  Train Loss : 0.03903 Val Loss : 0.45249   BatchID= 0   Val_AUC=0.8488   Best_Val_AUC=0.8488
# Epoch : 84
# Iteration started
# Epoch : 085  Train Loss : 0.03677 Val Loss : 0.42885   BatchID= 0   Val_AUC=0.8112   Best_Val_AUC=0.8488
# Epoch : 85
# Iteration started
# Epoch : 086  Train Loss : 0.04254 Val Loss : 0.46792   BatchID= 0   Val_AUC=0.8605   Best_Val_AUC=0.8605
# Epoch : 86
# Iteration started
# Epoch : 087  Train Loss : 0.04702 Val Loss : 0.38644   BatchID= 0   Val_AUC=0.7811   Best_Val_AUC=0.8605
# Epoch : 87
# Iteration started
# Epoch : 088  Train Loss : 0.04419 Val Loss : 0.41368   BatchID= 0   Val_AUC=0.8555   Best_Val_AUC=0.8605
# Epoch : 88
# Iteration started
# Epoch : 089  Train Loss : 0.04699 Val Loss : 0.46750   BatchID= 0   Val_AUC=0.8229   Best_Val_AUC=0.8605
# Epoch : 89
# Iteration started
# Epoch : 090  Train Loss : 0.04588 Val Loss : 0.35440   BatchID= 0   Val_AUC=0.8647   Best_Val_AUC=0.8647
# Epoch : 90
# Iteration started
# Epoch : 091  Train Loss : 0.03866 Val Loss : 0.53952   BatchID= 0   Val_AUC=0.8271   Best_Val_AUC=0.8647
# Epoch : 91
# Iteration started
# Epoch : 092  Train Loss : 0.03466 Val Loss : 0.37514   BatchID= 0   Val_AUC=0.8622   Best_Val_AUC=0.8647
# Epoch : 92
# Iteration started
# Epoch : 093  Train Loss : 0.03548 Val Loss : 0.41934   BatchID= 0   Val_AUC=0.8513   Best_Val_AUC=0.8647
# Epoch : 93
# Iteration started
# Epoch : 094  Train Loss : 0.03496 Val Loss : 0.40008   BatchID= 0   Val_AUC=0.8563   Best_Val_AUC=0.8647
# Epoch : 94
# Iteration started
# Epoch : 095  Train Loss : 0.03765 Val Loss : 0.41026   BatchID= 0   Val_AUC=0.8304   Best_Val_AUC=0.8647
# Epoch : 95
# Iteration started
# Epoch : 096  Train Loss : 0.03425 Val Loss : 0.34104   BatchID= 0   Val_AUC=0.8613   Best_Val_AUC=0.8647
# Epoch : 96
# Iteration started
# Epoch : 097  Train Loss : 0.03097 Val Loss : 0.48511   BatchID= 0   Val_AUC=0.8312   Best_Val_AUC=0.8647
# Epoch : 97
# Iteration started
# Epoch : 098  Train Loss : 0.03240 Val Loss : 0.37066   BatchID= 0   Val_AUC=0.8471   Best_Val_AUC=0.8647
# Epoch : 98
# Iteration started
# Epoch : 099  Train Loss : 0.02774 Val Loss : 0.38732   BatchID= 0   Val_AUC=0.8755   Best_Val_AUC=0.8755
# Epoch : 99
# Iteration started
# Epoch : 100  Train Loss : 0.02771 Val Loss : 0.37666   BatchID= 0   Val_AUC=0.8530   Best_Val_AUC=0.8755
# Epoch : 100
# Iteration started
# Epoch : 101  Train Loss : 0.02549 Val Loss : 0.34699   BatchID= 0   Val_AUC=0.8622   Best_Val_AUC=0.8755
# Epoch : 101
# Iteration started
# Epoch : 102  Train Loss : 0.02632 Val Loss : 0.36031   BatchID= 0   Val_AUC=0.8271   Best_Val_AUC=0.8755
# Epoch : 102
# Iteration started
# Epoch : 103  Train Loss : 0.02711 Val Loss : 0.39126   BatchID= 0   Val_AUC=0.8638   Best_Val_AUC=0.8755
# Epoch : 103
# Iteration started
# Epoch : 104  Train Loss : 0.02547 Val Loss : 0.35556   BatchID= 0   Val_AUC=0.8363   Best_Val_AUC=0.8755
# Epoch : 104
# Iteration started
# Epoch : 105  Train Loss : 0.02420 Val Loss : 0.34015   BatchID= 0   Val_AUC=0.8688   Best_Val_AUC=0.8755
# Epoch : 105
# Iteration started
# Epoch : 106  Train Loss : 0.03009 Val Loss : 0.37188   BatchID= 0   Val_AUC=0.8262   Best_Val_AUC=0.8755
# Epoch : 106
# Iteration started
# Epoch : 107  Train Loss : 0.02735 Val Loss : 0.39961   BatchID= 0   Val_AUC=0.8546   Best_Val_AUC=0.8755
# Epoch : 107
# Iteration started
# Epoch : 108  Train Loss : 0.02775 Val Loss : 0.40475   BatchID= 0   Val_AUC=0.8287   Best_Val_AUC=0.8755
# Epoch : 108
# Iteration started
# Epoch : 109  Train Loss : 0.02772 Val Loss : 0.33753   BatchID= 0   Val_AUC=0.8797   Best_Val_AUC=0.8797
# Epoch : 109
# Iteration started
# Epoch : 110  Train Loss : 0.02309 Val Loss : 0.37292   BatchID= 0   Val_AUC=0.8396   Best_Val_AUC=0.8797
# Epoch : 110
# Iteration started
# Epoch : 111  Train Loss : 0.02575 Val Loss : 0.37566   BatchID= 0   Val_AUC=0.8789   Best_Val_AUC=0.8797
# Epoch : 111
# Iteration started
# Epoch : 112  Train Loss : 0.02155 Val Loss : 0.27813   BatchID= 0   Val_AUC=0.8638   Best_Val_AUC=0.8797
# Epoch : 112
# Iteration started
# Epoch : 113  Train Loss : 0.02103 Val Loss : 0.38719   BatchID= 0   Val_AUC=0.8789   Best_Val_AUC=0.8797
# Epoch : 113
# Iteration started
# Epoch : 114  Train Loss : 0.01597 Val Loss : 0.33022   BatchID= 0   Val_AUC=0.8772   Best_Val_AUC=0.8797
# Epoch : 114
# Iteration started
# Epoch : 115  Train Loss : 0.01219 Val Loss : 0.34109   BatchID= 0   Val_AUC=0.8830   Best_Val_AUC=0.8830
# Epoch : 115
# Iteration started
# Epoch : 116  Train Loss : 0.01647 Val Loss : 0.36577   BatchID= 0   Val_AUC=0.8538   Best_Val_AUC=0.8830
# Epoch : 116
# Iteration started
# Epoch : 117  Train Loss : 0.01655 Val Loss : 0.22279   BatchID= 0   Val_AUC=0.8881   Best_Val_AUC=0.8881
# Epoch : 117
# Iteration started
# Epoch : 118  Train Loss : 0.01687 Val Loss : 0.41479   BatchID= 0   Val_AUC=0.8421   Best_Val_AUC=0.8881
# Epoch : 118
# Iteration started
# Epoch : 119  Train Loss : 0.01398 Val Loss : 0.26088   BatchID= 0   Val_AUC=0.8672   Best_Val_AUC=0.8881
# Epoch : 119
# Iteration started
# Epoch : 120  Train Loss : 0.01326 Val Loss : 0.38001   BatchID= 0   Val_AUC=0.8446   Best_Val_AUC=0.8881
# Epoch : 120
# Iteration started
# Epoch : 121  Train Loss : 0.01445 Val Loss : 0.22228   BatchID= 0   Val_AUC=0.8613   Best_Val_AUC=0.8881
# Epoch : 121
# Iteration started
# Epoch : 122  Train Loss : 0.01526 Val Loss : 0.47782   BatchID= 0   Val_AUC=0.8296   Best_Val_AUC=0.8881
# Epoch : 122
# Iteration started
# Epoch : 123  Train Loss : 0.01761 Val Loss : 0.27517   BatchID= 0   Val_AUC=0.8939   Best_Val_AUC=0.8939
# Epoch : 123
# Iteration started
# Epoch : 124  Train Loss : 0.00813 Val Loss : 0.31102   BatchID= 0   Val_AUC=0.9064   Best_Val_AUC=0.9064
# Epoch : 124
# Iteration started
# Epoch : 125  Train Loss : 0.01000 Val Loss : 0.29664   BatchID= 0   Val_AUC=0.8396   Best_Val_AUC=0.9064
# Epoch : 125
# Iteration started
# Epoch : 126  Train Loss : 0.01013 Val Loss : 0.26443   BatchID= 0   Val_AUC=0.9014   Best_Val_AUC=0.9064
# Epoch : 126
# Iteration started
# Epoch : 127  Train Loss : 0.01159 Val Loss : 0.37210   BatchID= 0   Val_AUC=0.8596   Best_Val_AUC=0.9064
# Epoch : 127
# Iteration started
# Epoch : 128  Train Loss : 0.00819 Val Loss : 0.25865   BatchID= 0   Val_AUC=0.8947   Best_Val_AUC=0.9064
# Epoch : 128
# Iteration started
# Epoch : 129  Train Loss : 0.00703 Val Loss : 0.36602   BatchID= 0   Val_AUC=0.8697   Best_Val_AUC=0.9064
# Epoch : 129
# Iteration started
# Epoch : 130  Train Loss : 0.00703 Val Loss : 0.29739   BatchID= 0   Val_AUC=0.8847   Best_Val_AUC=0.9064
# Epoch : 130
# Iteration started
# Epoch : 131  Train Loss : 0.00603 Val Loss : 0.41507   BatchID= 0   Val_AUC=0.8655   Best_Val_AUC=0.9064
# Epoch : 131
# Iteration started
# Epoch : 132  Train Loss : 0.00545 Val Loss : 0.26997   BatchID= 0   Val_AUC=0.9081   Best_Val_AUC=0.9081
# Epoch : 132
# Iteration started
# Epoch : 133  Train Loss : 0.00945 Val Loss : 0.40712   BatchID= 0   Val_AUC=0.8388   Best_Val_AUC=0.9081
# Epoch : 133
# Iteration started
# Epoch : 134  Train Loss : 0.00824 Val Loss : 0.22041   BatchID= 0   Val_AUC=0.8939   Best_Val_AUC=0.9081
# Epoch : 134
# Iteration started
# Epoch : 135  Train Loss : 0.00612 Val Loss : 0.33754   BatchID= 0   Val_AUC=0.8530   Best_Val_AUC=0.9081
# Epoch : 135
# Iteration started
# Epoch : 136  Train Loss : 0.00606 Val Loss : 0.27426   BatchID= 0   Val_AUC=0.9064   Best_Val_AUC=0.9081
# Epoch : 136
# Iteration started
# Epoch : 137  Train Loss : 0.00290 Val Loss : 0.37837   BatchID= 0   Val_AUC=0.8672   Best_Val_AUC=0.9081
# Epoch : 137
# Iteration started
# Epoch : 138  Train Loss : 0.00198 Val Loss : 0.25944   BatchID= 0   Val_AUC=0.9039   Best_Val_AUC=0.9081
# Epoch : 138
# Iteration started
# Epoch : 139  Train Loss : 0.00111 Val Loss : 0.35631   BatchID= 0   Val_AUC=0.8906   Best_Val_AUC=0.9081
# Epoch : 139
# Iteration started
# Epoch : 140  Train Loss : 0.00011 Val Loss : 0.38538   BatchID= 0   Val_AUC=0.8764   Best_Val_AUC=0.9081
# Epoch : 140
# Iteration started
# Epoch : 141  Train Loss : -0.00017 Val Loss : 0.35217   BatchID= 0   Val_AUC=0.8864   Best_Val_AUC=0.9081
# Epoch : 141
# Iteration started
# Epoch : 142  Train Loss : -0.00043 Val Loss : 0.36781   BatchID= 0   Val_AUC=0.8797   Best_Val_AUC=0.9081
# Epoch : 142
# Iteration started
# Epoch : 143  Train Loss : 0.00023 Val Loss : 0.34227   BatchID= 0   Val_AUC=0.8830   Best_Val_AUC=0.9081
# Epoch : 143
# Iteration started
# Epoch : 144  Train Loss : 0.00113 Val Loss : 0.45226   BatchID= 0   Val_AUC=0.8914   Best_Val_AUC=0.9081
# Epoch : 144
# Iteration started
# Epoch : 145  Train Loss : -0.00003 Val Loss : 0.29961   BatchID= 0   Val_AUC=0.8922   Best_Val_AUC=0.9081
# Epoch : 145
# Iteration started
# Epoch : 146  Train Loss : -0.00107 Val Loss : 0.38434   BatchID= 0   Val_AUC=0.8914   Best_Val_AUC=0.9081
# Epoch : 146
# Iteration started
# Epoch : 147  Train Loss : -0.00191 Val Loss : 0.35101   BatchID= 0   Val_AUC=0.8872   Best_Val_AUC=0.9081
# Epoch : 147
# Iteration started
# Epoch : 148  Train Loss : -0.00110 Val Loss : 0.37484   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9106
# Epoch : 148
# Iteration started
# Epoch : 149  Train Loss : -0.00182 Val Loss : 0.41938   BatchID= 0   Val_AUC=0.8855   Best_Val_AUC=0.9106
# Epoch : 149
# Iteration started
# Epoch : 150  Train Loss : -0.00357 Val Loss : 0.36763   BatchID= 0   Val_AUC=0.8989   Best_Val_AUC=0.9106
# Epoch : 150
# Iteration started
# Epoch : 151  Train Loss : -0.00424 Val Loss : 0.42727   BatchID= 0   Val_AUC=0.8972   Best_Val_AUC=0.9106
# Epoch : 151
# Iteration started
# Epoch : 152  Train Loss : -0.00539 Val Loss : 0.36768   BatchID= 0   Val_AUC=0.9023   Best_Val_AUC=0.9106
# Epoch : 152
# Iteration started
# Epoch : 153  Train Loss : -0.00457 Val Loss : 0.40904   BatchID= 0   Val_AUC=0.8956   Best_Val_AUC=0.9106
# Epoch : 153
# Iteration started
# Epoch : 154  Train Loss : -0.00475 Val Loss : 0.35168   BatchID= 0   Val_AUC=0.8981   Best_Val_AUC=0.9106
# Epoch : 154
# Iteration started
# Epoch : 155  Train Loss : -0.00146 Val Loss : 0.42894   BatchID= 0   Val_AUC=0.8972   Best_Val_AUC=0.9106
# Epoch : 155
# Iteration started
# Epoch : 156  Train Loss : -0.00490 Val Loss : 0.42772   BatchID= 0   Val_AUC=0.8956   Best_Val_AUC=0.9106
# Epoch : 156
# Iteration started
# Epoch : 157  Train Loss : -0.00585 Val Loss : 0.37414   BatchID= 0   Val_AUC=0.8864   Best_Val_AUC=0.9106
# Epoch : 157
# Iteration started
# Epoch : 158  Train Loss : -0.00555 Val Loss : 0.46150   BatchID= 0   Val_AUC=0.8839   Best_Val_AUC=0.9106
# Epoch : 158
# Iteration started
# Epoch : 159  Train Loss : -0.00614 Val Loss : 0.44263   BatchID= 0   Val_AUC=0.8855   Best_Val_AUC=0.9106
# Epoch : 159
# Iteration started
# Epoch : 160  Train Loss : -0.00513 Val Loss : 0.41043   BatchID= 0   Val_AUC=0.8956   Best_Val_AUC=0.9106
# Epoch : 160
# Iteration started
# Epoch : 161  Train Loss : -0.00514 Val Loss : 0.48111   BatchID= 0   Val_AUC=0.8789   Best_Val_AUC=0.9106
# Epoch : 161
# Iteration started
# Epoch : 162  Train Loss : -0.00636 Val Loss : 0.37911   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9106
# Epoch : 162
# Iteration started
# Epoch : 163  Train Loss : -0.00739 Val Loss : 0.48905   BatchID= 0   Val_AUC=0.8755   Best_Val_AUC=0.9106
# Epoch : 163
# Iteration started
# Epoch : 164  Train Loss : -0.00778 Val Loss : 0.39226   BatchID= 0   Val_AUC=0.9081   Best_Val_AUC=0.9106
# Epoch : 164
# Iteration started
# Epoch : 165  Train Loss : -0.00858 Val Loss : 0.46340   BatchID= 0   Val_AUC=0.8989   Best_Val_AUC=0.9106
# Epoch : 165
# Iteration started
# Epoch : 166  Train Loss : -0.00796 Val Loss : 0.41350   BatchID= 0   Val_AUC=0.9048   Best_Val_AUC=0.9106
# Epoch : 166
# Iteration started
# Epoch : 167  Train Loss : -0.00831 Val Loss : 0.45985   BatchID= 0   Val_AUC=0.9039   Best_Val_AUC=0.9106
# Epoch : 167
# Iteration started
# Epoch : 168  Train Loss : -0.00880 Val Loss : 0.43983   BatchID= 0   Val_AUC=0.9073   Best_Val_AUC=0.9106
# Epoch : 168
# Iteration started
# Epoch : 169  Train Loss : -0.00945 Val Loss : 0.46813   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9140
# Epoch : 169
# Iteration started
# Epoch : 170  Train Loss : -0.00833 Val Loss : 0.43790   BatchID= 0   Val_AUC=0.8964   Best_Val_AUC=0.9140
# Epoch : 170
# Iteration started
# Epoch : 171  Train Loss : -0.00876 Val Loss : 0.41905   BatchID= 0   Val_AUC=0.9181   Best_Val_AUC=0.9181
# Epoch : 171
# Iteration started
# Epoch : 172  Train Loss : -0.00854 Val Loss : 0.48401   BatchID= 0   Val_AUC=0.8939   Best_Val_AUC=0.9181
# Epoch : 172
# Iteration started
# Epoch : 173  Train Loss : -0.01075 Val Loss : 0.41227   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9181
# Epoch : 173
# Iteration started
# Epoch : 174  Train Loss : -0.01025 Val Loss : 0.47547   BatchID= 0   Val_AUC=0.8906   Best_Val_AUC=0.9181
# Epoch : 174
# Iteration started
# Epoch : 175  Train Loss : -0.01143 Val Loss : 0.43330   BatchID= 0   Val_AUC=0.9064   Best_Val_AUC=0.9181
# Epoch : 175
# Iteration started
# Epoch : 176  Train Loss : -0.00930 Val Loss : 0.48697   BatchID= 0   Val_AUC=0.9006   Best_Val_AUC=0.9181
# Epoch : 176
# Iteration started
# Epoch : 177  Train Loss : -0.01012 Val Loss : 0.43470   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9181
# Epoch : 177
# Iteration started
# Epoch : 178  Train Loss : -0.00962 Val Loss : 0.49148   BatchID= 0   Val_AUC=0.8964   Best_Val_AUC=0.9181
# Epoch : 178
# Iteration started
# Epoch : 179  Train Loss : -0.01147 Val Loss : 0.42077   BatchID= 0   Val_AUC=0.9081   Best_Val_AUC=0.9181
# Epoch : 179
# Iteration started
# Epoch : 180  Train Loss : -0.00904 Val Loss : 0.49418   BatchID= 0   Val_AUC=0.9014   Best_Val_AUC=0.9181
# Epoch : 180
# Iteration started
# Epoch : 181  Train Loss : -0.01007 Val Loss : 0.45741   BatchID= 0   Val_AUC=0.9039   Best_Val_AUC=0.9181
# Epoch : 181
# Iteration started
# Epoch : 182  Train Loss : -0.01246 Val Loss : 0.50597   BatchID= 0   Val_AUC=0.8914   Best_Val_AUC=0.9181
# Epoch : 182
# Iteration started
# Epoch : 183  Train Loss : -0.01065 Val Loss : 0.44147   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9181
# Epoch : 183
# Iteration started
# Epoch : 184  Train Loss : -0.00973 Val Loss : 0.47294   BatchID= 0   Val_AUC=0.8997   Best_Val_AUC=0.9181
# Epoch : 184
# Iteration started
# Epoch : 185  Train Loss : -0.01056 Val Loss : 0.50421   BatchID= 0   Val_AUC=0.8939   Best_Val_AUC=0.9181
# Epoch : 185
# Iteration started
# Epoch : 186  Train Loss : -0.01110 Val Loss : 0.49321   BatchID= 0   Val_AUC=0.9014   Best_Val_AUC=0.9181
# Epoch : 186
# Iteration started
# Epoch : 187  Train Loss : -0.01147 Val Loss : 0.51730   BatchID= 0   Val_AUC=0.9006   Best_Val_AUC=0.9181
# Epoch : 187
# Iteration started
# Epoch : 188  Train Loss : -0.00858 Val Loss : 0.52881   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9181
# Epoch : 188
# Iteration started
# Epoch : 189  Train Loss : -0.01198 Val Loss : 0.51336   BatchID= 0   Val_AUC=0.8972   Best_Val_AUC=0.9181
# Epoch : 189
# Iteration started
# Epoch : 190  Train Loss : -0.01093 Val Loss : 0.51212   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 190
# Iteration started
# Epoch : 191  Train Loss : -0.00898 Val Loss : 0.54237   BatchID= 0   Val_AUC=0.9064   Best_Val_AUC=0.9181
# Epoch : 191
# Iteration started
# Epoch : 192  Train Loss : -0.01160 Val Loss : 0.57394   BatchID= 0   Val_AUC=0.8956   Best_Val_AUC=0.9181
# Epoch : 192
# Iteration started
# Epoch : 193  Train Loss : -0.01314 Val Loss : 0.55032   BatchID= 0   Val_AUC=0.9048   Best_Val_AUC=0.9181
# Epoch : 193
# Iteration started
# Epoch : 194  Train Loss : -0.01313 Val Loss : 0.53599   BatchID= 0   Val_AUC=0.8997   Best_Val_AUC=0.9181
# Epoch : 194
# Iteration started
# Epoch : 195  Train Loss : -0.01190 Val Loss : 0.55233   BatchID= 0   Val_AUC=0.8931   Best_Val_AUC=0.9181
# Epoch : 195
# Iteration started
# Epoch : 196  Train Loss : -0.01181 Val Loss : 0.49983   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 196
# Iteration started
# Epoch : 197  Train Loss : -0.01242 Val Loss : 0.53179   BatchID= 0   Val_AUC=0.9006   Best_Val_AUC=0.9181
# Epoch : 197
# Iteration started
# Epoch : 198  Train Loss : -0.01371 Val Loss : 0.53538   BatchID= 0   Val_AUC=0.9056   Best_Val_AUC=0.9181
# Epoch : 198
# Iteration started
# Epoch : 199  Train Loss : -0.01383 Val Loss : 0.52869   BatchID= 0   Val_AUC=0.9056   Best_Val_AUC=0.9181
# Epoch : 199
# Iteration started
# Epoch : 200  Train Loss : -0.01246 Val Loss : 0.52851   BatchID= 0   Val_AUC=0.9023   Best_Val_AUC=0.9181
# Epoch : 200
# Iteration started
# Epoch : 201  Train Loss : -0.01209 Val Loss : 0.56263   BatchID= 0   Val_AUC=0.8989   Best_Val_AUC=0.9181
# Epoch : 201
# Iteration started
# Epoch : 202  Train Loss : -0.01249 Val Loss : 0.55292   BatchID= 0   Val_AUC=0.9056   Best_Val_AUC=0.9181
# Epoch : 202
# Iteration started
# Epoch : 203  Train Loss : -0.01202 Val Loss : 0.54398   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9181
# Epoch : 203
# Iteration started
# Epoch : 204  Train Loss : -0.01070 Val Loss : 0.55019   BatchID= 0   Val_AUC=0.9081   Best_Val_AUC=0.9181
# Epoch : 204
# Iteration started
# Epoch : 205  Train Loss : -0.01330 Val Loss : 0.55415   BatchID= 0   Val_AUC=0.9048   Best_Val_AUC=0.9181
# Epoch : 205
# Iteration started
# Epoch : 206  Train Loss : -0.01336 Val Loss : 0.54347   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9181
# Epoch : 206
# Iteration started
# Epoch : 207  Train Loss : -0.01407 Val Loss : 0.54474   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9181
# Epoch : 207
# Iteration started
# Epoch : 208  Train Loss : -0.01326 Val Loss : 0.58261   BatchID= 0   Val_AUC=0.9064   Best_Val_AUC=0.9181
# Epoch : 208
# Iteration started
# Epoch : 209  Train Loss : -0.01197 Val Loss : 0.60260   BatchID= 0   Val_AUC=0.9014   Best_Val_AUC=0.9181
# Epoch : 209
# Iteration started
# Epoch : 210  Train Loss : -0.01311 Val Loss : 0.57299   BatchID= 0   Val_AUC=0.9073   Best_Val_AUC=0.9181
# Epoch : 210
# Iteration started
# Epoch : 211  Train Loss : -0.01435 Val Loss : 0.59994   BatchID= 0   Val_AUC=0.9039   Best_Val_AUC=0.9181
# Epoch : 211
# Iteration started
# Epoch : 212  Train Loss : -0.01214 Val Loss : 0.56225   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9181
# Epoch : 212
# Iteration started
# Epoch : 213  Train Loss : -0.01243 Val Loss : 0.58026   BatchID= 0   Val_AUC=0.9039   Best_Val_AUC=0.9181
# Epoch : 213
# Iteration started
# Epoch : 214  Train Loss : -0.01403 Val Loss : 0.57589   BatchID= 0   Val_AUC=0.9081   Best_Val_AUC=0.9181
# Epoch : 214
# Iteration started
# Epoch : 215  Train Loss : -0.01373 Val Loss : 0.56284   BatchID= 0   Val_AUC=0.9073   Best_Val_AUC=0.9181
# Epoch : 215
# Iteration started
# Epoch : 216  Train Loss : -0.01126 Val Loss : 0.60372   BatchID= 0   Val_AUC=0.9073   Best_Val_AUC=0.9181
# Epoch : 216
# Iteration started
# Epoch : 217  Train Loss : -0.01240 Val Loss : 0.58798   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9181
# Epoch : 217
# Iteration started
# Epoch : 218  Train Loss : -0.01365 Val Loss : 0.58560   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 218
# Iteration started
# Epoch : 219  Train Loss : -0.01438 Val Loss : 0.60055   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 219
# Iteration started
# Epoch : 220  Train Loss : -0.01409 Val Loss : 0.61227   BatchID= 0   Val_AUC=0.9073   Best_Val_AUC=0.9181
# Epoch : 220
# Iteration started
# Epoch : 221  Train Loss : -0.01389 Val Loss : 0.63099   BatchID= 0   Val_AUC=0.9039   Best_Val_AUC=0.9181
# Epoch : 221
# Iteration started
# Epoch : 222  Train Loss : -0.01463 Val Loss : 0.63186   BatchID= 0   Val_AUC=0.9048   Best_Val_AUC=0.9181
# Epoch : 222
# Iteration started
# Epoch : 223  Train Loss : -0.01195 Val Loss : 0.64074   BatchID= 0   Val_AUC=0.9006   Best_Val_AUC=0.9181
# Epoch : 223
# Iteration started
# Epoch : 224  Train Loss : -0.01373 Val Loss : 0.63294   BatchID= 0   Val_AUC=0.9006   Best_Val_AUC=0.9181
# Epoch : 224
# Iteration started
# Epoch : 225  Train Loss : -0.01234 Val Loss : 0.58510   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9181
# Epoch : 225
# Iteration started
# Epoch : 226  Train Loss : -0.01406 Val Loss : 0.62774   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9181
# Epoch : 226
# Iteration started
# Epoch : 227  Train Loss : -0.01339 Val Loss : 0.66344   BatchID= 0   Val_AUC=0.8989   Best_Val_AUC=0.9181
# Epoch : 227
# Iteration started
# Epoch : 228  Train Loss : -0.01075 Val Loss : 0.61802   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9181
# Epoch : 228
# Iteration started
# Epoch : 229  Train Loss : -0.01440 Val Loss : 0.64086   BatchID= 0   Val_AUC=0.9073   Best_Val_AUC=0.9181
# Epoch : 229
# Iteration started
# Epoch : 230  Train Loss : -0.01355 Val Loss : 0.61867   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9181
# Epoch : 230
# Iteration started
# Epoch : 231  Train Loss : -0.01343 Val Loss : 0.62931   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9181
# Epoch : 231
# Iteration started
# Epoch : 232  Train Loss : -0.01186 Val Loss : 0.65962   BatchID= 0   Val_AUC=0.9056   Best_Val_AUC=0.9181
# Epoch : 232
# Iteration started
# Epoch : 233  Train Loss : -0.01358 Val Loss : 0.65972   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9181
# Epoch : 233
# Iteration started
# Epoch : 234  Train Loss : -0.01315 Val Loss : 0.66650   BatchID= 0   Val_AUC=0.9039   Best_Val_AUC=0.9181
# Epoch : 234
# Iteration started
# Epoch : 235  Train Loss : -0.01328 Val Loss : 0.66172   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9181
# Epoch : 235
# Iteration started
# Epoch : 236  Train Loss : -0.01357 Val Loss : 0.63685   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 236
# Iteration started
# Epoch : 237  Train Loss : -0.01059 Val Loss : 0.66010   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 237
# Iteration started
# Epoch : 238  Train Loss : -0.01146 Val Loss : 0.67408   BatchID= 0   Val_AUC=0.9073   Best_Val_AUC=0.9181
# Epoch : 238
# Iteration started
# Epoch : 239  Train Loss : -0.01423 Val Loss : 0.68161   BatchID= 0   Val_AUC=0.8989   Best_Val_AUC=0.9181
# Epoch : 239
# Iteration started
# Epoch : 240  Train Loss : -0.01151 Val Loss : 0.67373   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9181
# Epoch : 240
# Iteration started
# Epoch : 241  Train Loss : -0.01253 Val Loss : 0.68639   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 241
# Iteration started
# Epoch : 242  Train Loss : -0.01224 Val Loss : 0.67651   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9181
# Epoch : 242
# Iteration started
# Epoch : 243  Train Loss : -0.01215 Val Loss : 0.71602   BatchID= 0   Val_AUC=0.9081   Best_Val_AUC=0.9181
# Epoch : 243
# Iteration started
# Epoch : 244  Train Loss : -0.01339 Val Loss : 0.72072   BatchID= 0   Val_AUC=0.9064   Best_Val_AUC=0.9181
# Epoch : 244
# Iteration started
# Epoch : 245  Train Loss : -0.01171 Val Loss : 0.72420   BatchID= 0   Val_AUC=0.9056   Best_Val_AUC=0.9181
# Epoch : 245
# Iteration started
# Epoch : 246  Train Loss : -0.01113 Val Loss : 0.73619   BatchID= 0   Val_AUC=0.9064   Best_Val_AUC=0.9181
# Epoch : 246
# Iteration started
# Epoch : 247  Train Loss : -0.01131 Val Loss : 0.74308   BatchID= 0   Val_AUC=0.9081   Best_Val_AUC=0.9181
# Epoch : 247
# Iteration started
# Epoch : 248  Train Loss : -0.01331 Val Loss : 0.75382   BatchID= 0   Val_AUC=0.9064   Best_Val_AUC=0.9181
# Epoch : 248
# Iteration started
# Epoch : 249  Train Loss : -0.01279 Val Loss : 0.73450   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 249
# Iteration started
# Epoch : 250  Train Loss : -0.01387 Val Loss : 0.73976   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 250
# Iteration started
# Epoch : 251  Train Loss : -0.01162 Val Loss : 0.74077   BatchID= 0   Val_AUC=0.9081   Best_Val_AUC=0.9181
# Epoch : 251
# Iteration started
# Epoch : 252  Train Loss : -0.01155 Val Loss : 0.72496   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 252
# Iteration started
# Epoch : 253  Train Loss : -0.01200 Val Loss : 0.74272   BatchID= 0   Val_AUC=0.9081   Best_Val_AUC=0.9181
# Epoch : 253
# Iteration started
# Epoch : 254  Train Loss : -0.01135 Val Loss : 0.75724   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9181
# Epoch : 254
# Iteration started
# Epoch : 255  Train Loss : -0.01261 Val Loss : 0.75016   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9181
# Epoch : 255
# Iteration started
# Epoch : 256  Train Loss : -0.01306 Val Loss : 0.73388   BatchID= 0   Val_AUC=0.9064   Best_Val_AUC=0.9181
# Epoch : 256
# Iteration started
# Epoch : 257  Train Loss : -0.01195 Val Loss : 0.74674   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 257
# Iteration started
# Epoch : 258  Train Loss : -0.01221 Val Loss : 0.72054   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9181
# Epoch : 258
# Iteration started
# Epoch : 259  Train Loss : -0.01255 Val Loss : 0.70224   BatchID= 0   Val_AUC=0.9081   Best_Val_AUC=0.9181
# Epoch : 259
# Iteration started
# Epoch : 260  Train Loss : -0.01096 Val Loss : 0.73878   BatchID= 0   Val_AUC=0.9081   Best_Val_AUC=0.9181
# Epoch : 260
# Iteration started
# Epoch : 261  Train Loss : -0.01266 Val Loss : 0.73453   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 261
# Iteration started
# Epoch : 262  Train Loss : -0.01149 Val Loss : 0.71739   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9181
# Epoch : 262
# Iteration started
# Epoch : 263  Train Loss : -0.00991 Val Loss : 0.77370   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 263
# Iteration started
# Epoch : 264  Train Loss : -0.01219 Val Loss : 0.76779   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 264
# Iteration started
# Epoch : 265  Train Loss : -0.01264 Val Loss : 0.76816   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 265
# Iteration started
# Epoch : 266  Train Loss : -0.01092 Val Loss : 0.76462   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9181
# Epoch : 266
# Iteration started
# Epoch : 267  Train Loss : -0.01298 Val Loss : 0.74822   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9181
# Epoch : 267
# Iteration started
# Epoch : 268  Train Loss : -0.01253 Val Loss : 0.75322   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9181
# Epoch : 268
# Iteration started
# Epoch : 269  Train Loss : -0.01150 Val Loss : 0.76620   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 269
# Iteration started
# Epoch : 270  Train Loss : -0.01260 Val Loss : 0.74359   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9181
# Epoch : 270
# Iteration started
# Epoch : 271  Train Loss : -0.01222 Val Loss : 0.74034   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9181
# Epoch : 271
# Iteration started
# Epoch : 272  Train Loss : -0.01337 Val Loss : 0.76407   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9181
# Epoch : 272
# Iteration started
# Epoch : 273  Train Loss : -0.01009 Val Loss : 0.76697   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 273
# Iteration started
# Epoch : 274  Train Loss : -0.01051 Val Loss : 0.78654   BatchID= 0   Val_AUC=0.9073   Best_Val_AUC=0.9181
# Epoch : 274
# Iteration started
# Epoch : 275  Train Loss : -0.00951 Val Loss : 0.75171   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9181
# Epoch : 275
# Iteration started
# Epoch : 276  Train Loss : -0.00761 Val Loss : 0.80417   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9181
# Epoch : 276
# Iteration started
# Epoch : 277  Train Loss : -0.00986 Val Loss : 0.80671   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9181
# Epoch : 277
# Iteration started
# Epoch : 278  Train Loss : -0.01169 Val Loss : 0.81310   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9181
# Epoch : 278
# Iteration started
# Epoch : 279  Train Loss : -0.01115 Val Loss : 0.81207   BatchID= 0   Val_AUC=0.9173   Best_Val_AUC=0.9181
# Epoch : 279
# Iteration started
# Epoch : 280  Train Loss : -0.01130 Val Loss : 0.83616   BatchID= 0   Val_AUC=0.9073   Best_Val_AUC=0.9181
# Epoch : 280
# Iteration started
# Epoch : 281  Train Loss : -0.01004 Val Loss : 0.87217   BatchID= 0   Val_AUC=0.9048   Best_Val_AUC=0.9181
# Epoch : 281
# Iteration started
# Epoch : 282  Train Loss : -0.01214 Val Loss : 0.86497   BatchID= 0   Val_AUC=0.9056   Best_Val_AUC=0.9181
# Epoch : 282
# Iteration started
# Epoch : 283  Train Loss : -0.00931 Val Loss : 0.85834   BatchID= 0   Val_AUC=0.9073   Best_Val_AUC=0.9181
# Epoch : 283
# Iteration started
# Epoch : 284  Train Loss : -0.01019 Val Loss : 0.88564   BatchID= 0   Val_AUC=0.9064   Best_Val_AUC=0.9181
# Epoch : 284
# Iteration started
# Epoch : 285  Train Loss : -0.01042 Val Loss : 0.85190   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 285
# Iteration started
# Epoch : 286  Train Loss : -0.00888 Val Loss : 0.87070   BatchID= 0   Val_AUC=0.9073   Best_Val_AUC=0.9181
# Epoch : 286
# Iteration started
# Epoch : 287  Train Loss : -0.01155 Val Loss : 0.88454   BatchID= 0   Val_AUC=0.9031   Best_Val_AUC=0.9181
# Epoch : 287
# Iteration started
# Epoch : 288  Train Loss : -0.01057 Val Loss : 0.86673   BatchID= 0   Val_AUC=0.9081   Best_Val_AUC=0.9181
# Epoch : 288
# Iteration started
# Epoch : 289  Train Loss : -0.01199 Val Loss : 0.87482   BatchID= 0   Val_AUC=0.9048   Best_Val_AUC=0.9181
# Epoch : 289
# Iteration started
# Epoch : 290  Train Loss : -0.01162 Val Loss : 0.84021   BatchID= 0   Val_AUC=0.8989   Best_Val_AUC=0.9181
# Epoch : 290
# Iteration started
# Epoch : 291  Train Loss : -0.01037 Val Loss : 0.81940   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 291
# Iteration started
# Epoch : 292  Train Loss : -0.01127 Val Loss : 0.83868   BatchID= 0   Val_AUC=0.9056   Best_Val_AUC=0.9181
# Epoch : 292
# Iteration started
# Epoch : 293  Train Loss : -0.00915 Val Loss : 0.84197   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9181
# Epoch : 293
# Iteration started
# Epoch : 294  Train Loss : -0.00976 Val Loss : 0.83813   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9181
# Epoch : 294
# Iteration started
# Epoch : 295  Train Loss : -0.00892 Val Loss : 0.84394   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 295
# Iteration started
# Epoch : 296  Train Loss : -0.01062 Val Loss : 0.84749   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9181
# Epoch : 296
# Iteration started
# Epoch : 297  Train Loss : -0.00967 Val Loss : 0.87114   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 297
# Iteration started
# Epoch : 298  Train Loss : -0.00962 Val Loss : 0.88231   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9181
# Epoch : 298
# Iteration started
# Epoch : 299  Train Loss : -0.01063 Val Loss : 0.89344   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 299
# Iteration started
# Epoch : 300  Train Loss : -0.00971 Val Loss : 0.91072   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9181
# Epoch : 300
# Iteration started
# Epoch : 301  Train Loss : -0.00854 Val Loss : 0.91013   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9181
# Epoch : 301
# Iteration started
# Epoch : 302  Train Loss : -0.01002 Val Loss : 0.91578   BatchID= 0   Val_AUC=0.9073   Best_Val_AUC=0.9181
# Epoch : 302
# Iteration started
# Epoch : 303  Train Loss : -0.00899 Val Loss : 0.95677   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 303
# Iteration started
# Epoch : 304  Train Loss : -0.01055 Val Loss : 0.95069   BatchID= 0   Val_AUC=0.9031   Best_Val_AUC=0.9181
# Epoch : 304
# Iteration started
# Epoch : 305  Train Loss : -0.00914 Val Loss : 0.90341   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9181
# Epoch : 305
# Iteration started
# Epoch : 306  Train Loss : -0.00956 Val Loss : 0.90921   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 306
# Iteration started
# Epoch : 307  Train Loss : -0.01083 Val Loss : 0.89777   BatchID= 0   Val_AUC=0.9081   Best_Val_AUC=0.9181
# Epoch : 307
# Iteration started
# Epoch : 308  Train Loss : -0.00998 Val Loss : 0.87661   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9181
# Epoch : 308
# Iteration started
# Epoch : 309  Train Loss : -0.01094 Val Loss : 0.86556   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 309
# Iteration started
# Epoch : 310  Train Loss : -0.00997 Val Loss : 0.88518   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 310
# Iteration started
# Epoch : 311  Train Loss : -0.00978 Val Loss : 0.88956   BatchID= 0   Val_AUC=0.9056   Best_Val_AUC=0.9181
# Epoch : 311
# Iteration started
# Epoch : 312  Train Loss : -0.00925 Val Loss : 0.89441   BatchID= 0   Val_AUC=0.9064   Best_Val_AUC=0.9181
# Epoch : 312
# Iteration started
# Epoch : 313  Train Loss : -0.00897 Val Loss : 0.90927   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9181
# Epoch : 313
# Iteration started
# Epoch : 314  Train Loss : -0.00996 Val Loss : 0.90220   BatchID= 0   Val_AUC=0.9056   Best_Val_AUC=0.9181
# Epoch : 314
# Iteration started
# Epoch : 315  Train Loss : -0.01056 Val Loss : 0.88283   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 315
# Iteration started
# Epoch : 316  Train Loss : -0.00684 Val Loss : 0.90307   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9181
# Epoch : 316
# Iteration started
# Epoch : 317  Train Loss : -0.00950 Val Loss : 0.89483   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9181
# Epoch : 317
# Iteration started
# Epoch : 318  Train Loss : -0.00925 Val Loss : 0.90025   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9181
# Epoch : 318
# Iteration started
# Epoch : 319  Train Loss : -0.00839 Val Loss : 0.92878   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9181
# Epoch : 319
# Iteration started
# Epoch : 320  Train Loss : -0.00953 Val Loss : 0.92382   BatchID= 0   Val_AUC=0.9064   Best_Val_AUC=0.9181
# Epoch : 320
# Iteration started
# Epoch : 321  Train Loss : -0.01015 Val Loss : 0.92406   BatchID= 0   Val_AUC=0.9064   Best_Val_AUC=0.9181
# Epoch : 321
# Iteration started
# Epoch : 322  Train Loss : -0.00863 Val Loss : 0.93118   BatchID= 0   Val_AUC=0.9081   Best_Val_AUC=0.9181
# Epoch : 322
# Iteration started
# Epoch : 323  Train Loss : -0.00826 Val Loss : 0.92853   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 323
# Iteration started
# Epoch : 324  Train Loss : -0.00707 Val Loss : 0.95543   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9181
# Epoch : 324
# Iteration started
# Epoch : 325  Train Loss : -0.00862 Val Loss : 0.96114   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9181
# Epoch : 325
# Iteration started
# Epoch : 326  Train Loss : -0.00896 Val Loss : 0.96441   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 326
# Iteration started
# Epoch : 327  Train Loss : -0.00928 Val Loss : 0.95764   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 327
# Iteration started
# Epoch : 328  Train Loss : -0.00896 Val Loss : 0.95721   BatchID= 0   Val_AUC=0.9048   Best_Val_AUC=0.9181
# Epoch : 328
# Iteration started
# Epoch : 329  Train Loss : -0.00953 Val Loss : 0.95404   BatchID= 0   Val_AUC=0.9039   Best_Val_AUC=0.9181
# Epoch : 329
# Iteration started
# Epoch : 330  Train Loss : -0.00929 Val Loss : 0.93578   BatchID= 0   Val_AUC=0.9064   Best_Val_AUC=0.9181
# Epoch : 330
# Iteration started
# Epoch : 331  Train Loss : -0.00782 Val Loss : 0.96545   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 331
# Iteration started
# Epoch : 332  Train Loss : -0.00869 Val Loss : 0.96458   BatchID= 0   Val_AUC=0.9073   Best_Val_AUC=0.9181
# Epoch : 332
# Iteration started
# Epoch : 333  Train Loss : -0.00881 Val Loss : 0.97432   BatchID= 0   Val_AUC=0.9081   Best_Val_AUC=0.9181
# Epoch : 333
# Iteration started
# Epoch : 334  Train Loss : -0.00897 Val Loss : 0.96752   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 334
# Iteration started
# Epoch : 335  Train Loss : -0.00782 Val Loss : 0.97640   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 335
# Iteration started
# Epoch : 336  Train Loss : -0.00749 Val Loss : 0.97631   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9181
# Epoch : 336
# Iteration started
# Epoch : 337  Train Loss : -0.00853 Val Loss : 0.97171   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9181
# Epoch : 337
# Iteration started
# Epoch : 338  Train Loss : -0.00767 Val Loss : 0.98027   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9181
# Epoch : 338
# Iteration started
# Epoch : 339  Train Loss : -0.00808 Val Loss : 0.99890   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9181
# Epoch : 339
# Iteration started
# Epoch : 340  Train Loss : -0.00826 Val Loss : 0.98209   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9181
# Epoch : 340
# Iteration started
# Epoch : 341  Train Loss : -0.00737 Val Loss : 0.98470   BatchID= 0   Val_AUC=0.9089   Best_Val_AUC=0.9181
# Epoch : 341
# Iteration started
# Epoch : 342  Train Loss : -0.00746 Val Loss : 0.99803   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9181
# Epoch : 342
# Iteration started
# Epoch : 343  Train Loss : -0.00896 Val Loss : 0.97666   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9181
# Epoch : 343
# Iteration started
# Epoch : 344  Train Loss : -0.00646 Val Loss : 1.00593   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9181
# Epoch : 344
# Iteration started
# Epoch : 345  Train Loss : -0.00693 Val Loss : 1.02912   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9181
# Epoch : 345
# Iteration started
# Epoch : 346  Train Loss : -0.00750 Val Loss : 1.02173   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9181
# Epoch : 346
# Iteration started
# Epoch : 347  Train Loss : -0.00814 Val Loss : 1.00735   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9181
# Epoch : 347
# Iteration started
# Epoch : 348  Train Loss : -0.00826 Val Loss : 0.99031   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9181
# Epoch : 348
# Iteration started
# Epoch : 349  Train Loss : -0.00710 Val Loss : 1.01093   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9181
# Epoch : 349
# Iteration started
# Epoch : 350  Train Loss : -0.00721 Val Loss : 1.01084   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9181
# Epoch : 350
# Iteration started
# Epoch : 351  Train Loss : -0.00840 Val Loss : 1.00339   BatchID= 0   Val_AUC=0.9081   Best_Val_AUC=0.9181
# Epoch : 351
# Iteration started
# Epoch : 352  Train Loss : -0.00750 Val Loss : 1.00464   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9181
# Epoch : 352
# Iteration started
# Epoch : 353  Train Loss : -0.00581 Val Loss : 1.01979   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9181
# Epoch : 353
# Iteration started
# ...
# Epoch : 885
# Iteration started
# Epoch : 886  Train Loss : -0.00009 Val Loss : 1.71265   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9190
# Epoch : 886
# Iteration started
# Epoch : 887  Train Loss : -0.00009 Val Loss : 1.71689   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9190
# Epoch : 887
# Iteration started
# Epoch : 888  Train Loss : -0.00011 Val Loss : 1.68208   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9190
# Epoch : 888
# Iteration started
# Epoch : 889  Train Loss : -0.00002 Val Loss : 1.70960   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9190
# Epoch : 889
# Iteration started
# Epoch : 890  Train Loss : -0.00011 Val Loss : 1.69950   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9190
# Epoch : 890
# Iteration started
# Epoch : 891  Train Loss : -0.00011 Val Loss : 1.69199   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9190
# Epoch : 891
# Iteration started
# Epoch : 892  Train Loss : -0.00007 Val Loss : 1.70043   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9190
# Epoch : 892
# Iteration started
# Epoch : 893  Train Loss : -0.00008 Val Loss : 1.70797   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9190
# Epoch : 893
# Iteration started
# Epoch : 894  Train Loss : -0.00010 Val Loss : 1.69415   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9190
# Epoch : 894
# Iteration started
# Epoch : 895  Train Loss : -0.00006 Val Loss : 1.70323   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9190
# Epoch : 895
# Iteration started
# Epoch : 896  Train Loss : -0.00005 Val Loss : 1.71321   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9190
# Epoch : 896
# Iteration started
# Epoch : 897  Train Loss : -0.00011 Val Loss : 1.68917   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 897
# Iteration started
# Epoch : 898  Train Loss : 0.00001 Val Loss : 1.72171   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9190
# Epoch : 898
# Iteration started
# Epoch : 899  Train Loss : -0.00005 Val Loss : 1.73281   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 899
# Iteration started
# Epoch : 900  Train Loss : -0.00009 Val Loss : 1.71468   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9190
# Epoch : 900
# Iteration started
# Epoch : 901  Train Loss : -0.00001 Val Loss : 1.73388   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9190
# Epoch : 901
# Iteration started
# Epoch : 902  Train Loss : -0.00012 Val Loss : 1.69822   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 902
# Iteration started
# Epoch : 903  Train Loss : -0.00010 Val Loss : 1.68175   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 903
# Iteration started
# Epoch : 904  Train Loss : -0.00010 Val Loss : 1.64591   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9190
# Epoch : 904
# Iteration started
# Epoch : 905  Train Loss : -0.00006 Val Loss : 1.66098   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9190
# Epoch : 905
# Iteration started
# Epoch : 906  Train Loss : -0.00008 Val Loss : 1.66021   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9190
# Epoch : 906
# Iteration started
# Epoch : 907  Train Loss : -0.00011 Val Loss : 1.64769   BatchID= 0   Val_AUC=0.9181   Best_Val_AUC=0.9190
# Epoch : 907
# Iteration started
# Epoch : 908  Train Loss : -0.00009 Val Loss : 1.63410   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9190
# Epoch : 908
# Iteration started
# Epoch : 909  Train Loss : -0.00010 Val Loss : 1.63465   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9190
# Epoch : 909
# Iteration started
# Epoch : 910  Train Loss : -0.00010 Val Loss : 1.61373   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 910
# Iteration started
# Epoch : 911  Train Loss : -0.00011 Val Loss : 1.59990   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 911
# Iteration started
# Epoch : 912  Train Loss : -0.00008 Val Loss : 1.60984   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9190
# Epoch : 912
# Iteration started
# Epoch : 913  Train Loss : -0.00009 Val Loss : 1.60790   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9190
# Epoch : 913
# Iteration started
# Epoch : 914  Train Loss : -0.00007 Val Loss : 1.60611   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9190
# Epoch : 914
# Iteration started
# Epoch : 915  Train Loss : -0.00008 Val Loss : 1.60254   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9190
# Epoch : 915
# Iteration started
# Epoch : 916  Train Loss : -0.00002 Val Loss : 1.57455   BatchID= 0   Val_AUC=0.9098   Best_Val_AUC=0.9190
# Epoch : 916
# Iteration started
# Epoch : 917  Train Loss : -0.00009 Val Loss : 1.56732   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9190
# Epoch : 917
# Iteration started
# Epoch : 918  Train Loss : 0.00004 Val Loss : 1.60326   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 918
# Iteration started
# Epoch : 919  Train Loss : -0.00009 Val Loss : 1.59782   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 919
# Iteration started
# Epoch : 920  Train Loss : -0.00008 Val Loss : 1.58842   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 920
# Iteration started
# Epoch : 921  Train Loss : -0.00006 Val Loss : 1.59704   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9190
# Epoch : 921
# Iteration started
# Epoch : 922  Train Loss : -0.00009 Val Loss : 1.57878   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9190
# Epoch : 922
# Iteration started
# Epoch : 923  Train Loss : -0.00002 Val Loss : 1.60771   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9190
# Epoch : 923
# Iteration started
# Epoch : 924  Train Loss : 0.00002 Val Loss : 1.63271   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9190
# Epoch : 924
# Iteration started
# Epoch : 925  Train Loss : -0.00008 Val Loss : 1.62264   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9190
# Epoch : 925
# Iteration started
# Epoch : 926  Train Loss : -0.00004 Val Loss : 1.61880   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9190
# Epoch : 926
# Iteration started
# Epoch : 927  Train Loss : -0.00004 Val Loss : 1.63398   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9190
# Epoch : 927
# Iteration started
# Epoch : 928  Train Loss : -0.00008 Val Loss : 1.61889   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9190
# Epoch : 928
# Iteration started
# Epoch : 929  Train Loss : -0.00009 Val Loss : 1.58888   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 929
# Iteration started
# Epoch : 930  Train Loss : -0.00007 Val Loss : 1.55917   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 930
# Iteration started
# Epoch : 931  Train Loss : -0.00006 Val Loss : 1.57836   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 931
# Iteration started
# Epoch : 932  Train Loss : -0.00008 Val Loss : 1.58503   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9190
# Epoch : 932
# Iteration started
# Epoch : 933  Train Loss : -0.00005 Val Loss : 1.59603   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9190
# Epoch : 933
# Iteration started
# Epoch : 934  Train Loss : -0.00008 Val Loss : 1.57990   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 934
# Iteration started
# Epoch : 935  Train Loss : -0.00007 Val Loss : 1.57096   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 935
# Iteration started
# Epoch : 936  Train Loss : -0.00007 Val Loss : 1.56514   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 936
# Iteration started
# Epoch : 937  Train Loss : -0.00004 Val Loss : 1.58169   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9190
# Epoch : 937
# Iteration started
# Epoch : 938  Train Loss : -0.00002 Val Loss : 1.61170   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9190
# Epoch : 938
# Iteration started
# Epoch : 939  Train Loss : -0.00008 Val Loss : 1.59556   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9190
# Epoch : 939
# Iteration started
# Epoch : 940  Train Loss : -0.00009 Val Loss : 1.56921   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9190
# Epoch : 940
# Iteration started
# Epoch : 941  Train Loss : -0.00008 Val Loss : 1.55677   BatchID= 0   Val_AUC=0.9106   Best_Val_AUC=0.9190
# Epoch : 941
# Iteration started
# Epoch : 942  Train Loss : -0.00004 Val Loss : 1.57103   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 942
# Iteration started
# Epoch : 943  Train Loss : -0.00007 Val Loss : 1.55968   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9190
# Epoch : 943
# Iteration started
# Epoch : 944  Train Loss : -0.00001 Val Loss : 1.59941   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9190
# Epoch : 944
# Iteration started
# Epoch : 945  Train Loss : -0.00007 Val Loss : 1.58187   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 945
# Iteration started
# Epoch : 946  Train Loss : -0.00002 Val Loss : 1.61248   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9190
# Epoch : 946
# Iteration started
# Epoch : 947  Train Loss : -0.00007 Val Loss : 1.59896   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9190
# Epoch : 947
# Iteration started
# Epoch : 948  Train Loss : -0.00007 Val Loss : 1.58589   BatchID= 0   Val_AUC=0.9114   Best_Val_AUC=0.9190
# Epoch : 948
# Iteration started
# Epoch : 949  Train Loss : -0.00006 Val Loss : 1.58174   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9190
# Epoch : 949
# Iteration started
# Epoch : 950  Train Loss : -0.00004 Val Loss : 1.58923   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 950
# Iteration started
# Epoch : 951  Train Loss : -0.00003 Val Loss : 1.61236   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9190
# Epoch : 951
# Iteration started
# Epoch : 952  Train Loss : -0.00003 Val Loss : 1.62644   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9190
# Epoch : 952
# Iteration started
# Epoch : 953  Train Loss : -0.00007 Val Loss : 1.60626   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9190
# Epoch : 953
# Iteration started
# Epoch : 954  Train Loss : -0.00006 Val Loss : 1.58348   BatchID= 0   Val_AUC=0.9123   Best_Val_AUC=0.9190
# Epoch : 954
# Iteration started
# Epoch : 955  Train Loss : -0.00006 Val Loss : 1.57732   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9190
# Epoch : 955
# Iteration started
# Epoch : 956  Train Loss : -0.00001 Val Loss : 1.55690   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9190
# Epoch : 956
# Iteration started
# Epoch : 957  Train Loss : -0.00006 Val Loss : 1.56206   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9190
# Epoch : 957
# Iteration started
# Epoch : 958  Train Loss : 0.00007 Val Loss : 1.59151   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9190
# Epoch : 958
# Iteration started
# Epoch : 959  Train Loss : -0.00006 Val Loss : 1.58809   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9190
# Epoch : 959
# Iteration started
# Epoch : 960  Train Loss : -0.00002 Val Loss : 1.60385   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9190
# Epoch : 960
# Iteration started
# Epoch : 961  Train Loss : -0.00007 Val Loss : 1.60458   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9190
# Epoch : 961
# Iteration started
# Epoch : 962  Train Loss : -0.00002 Val Loss : 1.58335   BatchID= 0   Val_AUC=0.9173   Best_Val_AUC=0.9190
# Epoch : 962
# Iteration started
# Epoch : 963  Train Loss : -0.00006 Val Loss : 1.58926   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9190
# Epoch : 963
# Iteration started
# Epoch : 964  Train Loss : -0.00007 Val Loss : 1.58783   BatchID= 0   Val_AUC=0.9181   Best_Val_AUC=0.9190
# Epoch : 964
# Iteration started
# Epoch : 965  Train Loss : -0.00003 Val Loss : 1.59873   BatchID= 0   Val_AUC=0.9173   Best_Val_AUC=0.9190
# Epoch : 965
# Iteration started
# Epoch : 966  Train Loss : -0.00000 Val Loss : 1.60479   BatchID= 0   Val_AUC=0.9198   Best_Val_AUC=0.9198
# Epoch : 966
# Iteration started
# Epoch : 967  Train Loss : -0.00004 Val Loss : 1.60311   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9198
# Epoch : 967
# Iteration started
# Epoch : 968  Train Loss : -0.00005 Val Loss : 1.59750   BatchID= 0   Val_AUC=0.9181   Best_Val_AUC=0.9198
# Epoch : 968
# Iteration started
# Epoch : 969  Train Loss : -0.00004 Val Loss : 1.57744   BatchID= 0   Val_AUC=0.9181   Best_Val_AUC=0.9198
# Epoch : 969
# Iteration started
# Epoch : 970  Train Loss : -0.00003 Val Loss : 1.59614   BatchID= 0   Val_AUC=0.9181   Best_Val_AUC=0.9198
# Epoch : 970
# Iteration started
# Epoch : 971  Train Loss : -0.00007 Val Loss : 1.58765   BatchID= 0   Val_AUC=0.9190   Best_Val_AUC=0.9198
# Epoch : 971
# Iteration started
# Epoch : 972  Train Loss : -0.00003 Val Loss : 1.60240   BatchID= 0   Val_AUC=0.9173   Best_Val_AUC=0.9198
# Epoch : 972
# Iteration started
# Epoch : 973  Train Loss : 0.00001 Val Loss : 1.62794   BatchID= 0   Val_AUC=0.9181   Best_Val_AUC=0.9198
# Epoch : 973
# Iteration started
# Epoch : 974  Train Loss : -0.00003 Val Loss : 1.63501   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9198
# Epoch : 974
# Iteration started
# Epoch : 975  Train Loss : -0.00004 Val Loss : 1.60804   BatchID= 0   Val_AUC=0.9181   Best_Val_AUC=0.9198
# Epoch : 975
# Iteration started
# Epoch : 976  Train Loss : -0.00005 Val Loss : 1.60661   BatchID= 0   Val_AUC=0.9173   Best_Val_AUC=0.9198
# Epoch : 976
# Iteration started
# Epoch : 977  Train Loss : -0.00001 Val Loss : 1.62062   BatchID= 0   Val_AUC=0.9181   Best_Val_AUC=0.9198
# Epoch : 977
# Iteration started
# Epoch : 978  Train Loss : -0.00006 Val Loss : 1.59497   BatchID= 0   Val_AUC=0.9190   Best_Val_AUC=0.9198
# Epoch : 978
# Iteration started
# Epoch : 979  Train Loss : 0.00001 Val Loss : 1.62495   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9198
# Epoch : 979
# Iteration started
# Epoch : 980  Train Loss : -0.00001 Val Loss : 1.64619   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9198
# Epoch : 980
# Iteration started
# Epoch : 981  Train Loss : -0.00005 Val Loss : 1.62900   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9198
# Epoch : 981
# Iteration started
# Epoch : 982  Train Loss : -0.00003 Val Loss : 1.63788   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9198
# Epoch : 982
# Iteration started
# Epoch : 983  Train Loss : -0.00003 Val Loss : 1.63595   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9198
# Epoch : 983
# Iteration started
# Epoch : 984  Train Loss : -0.00002 Val Loss : 1.65265   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9198
# Epoch : 984
# Iteration started
# Epoch : 985  Train Loss : -0.00005 Val Loss : 1.64715   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9198
# Epoch : 985
# Iteration started
# Epoch : 986  Train Loss : -0.00004 Val Loss : 1.64219   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9198
# Epoch : 986
# Iteration started
# Epoch : 987  Train Loss : -0.00004 Val Loss : 1.65293   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9198
# Epoch : 987
# Iteration started
# Epoch : 988  Train Loss : -0.00000 Val Loss : 1.67740   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9198
# Epoch : 988
# Iteration started
# Epoch : 989  Train Loss : 0.00001 Val Loss : 1.69263   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9198
# Epoch : 989
# Iteration started
# Epoch : 990  Train Loss : -0.00001 Val Loss : 1.70149   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9198
# Epoch : 990
# Iteration started
# Epoch : 991  Train Loss : -0.00005 Val Loss : 1.65824   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9198
# Epoch : 991
# Iteration started
# Epoch : 992  Train Loss : -0.00003 Val Loss : 1.64669   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9198
# Epoch : 992
# Iteration started
# Epoch : 993  Train Loss : 0.00002 Val Loss : 1.67300   BatchID= 0   Val_AUC=0.9131   Best_Val_AUC=0.9198
# Epoch : 993
# Iteration started
# Epoch : 994  Train Loss : -0.00002 Val Loss : 1.68841   BatchID= 0   Val_AUC=0.9140   Best_Val_AUC=0.9198
# Epoch : 994
# Iteration started
# Epoch : 995  Train Loss : -0.00004 Val Loss : 1.68832   BatchID= 0   Val_AUC=0.9148   Best_Val_AUC=0.9198
# Epoch : 995
# Iteration started
# Epoch : 996  Train Loss : 0.00002 Val Loss : 1.71620   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9198
# Epoch : 996
# Iteration started
# Epoch : 997  Train Loss : -0.00003 Val Loss : 1.70359   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9198
# Epoch : 997
# Iteration started
# Epoch : 998  Train Loss : -0.00004 Val Loss : 1.66960   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9198
# Epoch : 998
# Iteration started
# Epoch : 999  Train Loss : -0.00001 Val Loss : 1.66786   BatchID= 0   Val_AUC=0.9156   Best_Val_AUC=0.9198
# Epoch : 999
# Iteration started
# Epoch : 1000  Train Loss : -0.00003 Val Loss : 1.66070   BatchID= 0   Val_AUC=0.9165   Best_Val_AUC=0.9198
# Epoch : 1000
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
test_true.shape
# Out:
# (78, 1)

# %%
test_pred.shape
# Out:
# (78, 2)
